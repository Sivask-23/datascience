# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("dis.csv")
x=data.drop("diagnosis",axis=1)
y=data["diagnosis"]
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=1)
X_train
# Out:
#    sore_throat  fever  swollen_glands  congestion  headache
# 6            0      0               1           0         0
# 4            0      1               0           1         0
# 0            1      1               1           1         1
# 3            1      0               1           0         0
# 1            0      0               0           1         1
# 7            1      0               0           1         1
# 8            0      1               0           1         1
# 5            0      0               0           1         0

# %%
y_train
# Out:
# 6    Strep_Throat
# 4            cold
# 0    Strep_Throat
# 3    Strep_Throat
# 1         Allergy
# 7         Allergy
# 8            cold
# 5         Allergy
# Name: diagnosis, dtype: object

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(X_train,y_train)
Y_pred=dt.predict(X_test)
Y_pred
# Out:
# array(['cold', 'cold'], dtype=object)

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
plt.figure(figsize=(7,7))
plot_tree(dt,feature_names=x.columns,class_names=dt.classes_,filled=True,max_depth=5)
plt.show()

# %%
from sklearn.metrics import accuracy_score,classification_report
cr=classification_report(y_test,Y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#         cold       1.00      1.00      1.00         2
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
