# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
y = [2,3,4,5]
my_labels = ["oops","java","cpp","c#"]
exp = [0,0,0,0.1]
plt.pie(y,labels=my_labels,explode=exp,shadow=True)
plt.legend(title="Languages")
plt.title("Pie chart of Courses")
plt.show()
